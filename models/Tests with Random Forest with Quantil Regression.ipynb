# %% [markdown]
# Load the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

path = r"C:\Users\Surface\Masterarbeit\data\Baseline.xlsx"

df = pd.read_excel(path)

# %% [markdown]
# Transformation Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# get the numerical features
data_num = df.drop('x_Einzug [mm]', axis = 1)
# get the target values
data_labels = df['x_Einzug [mm]'].to_numpy()

# pipeline for preprocessing the data

# Standard Scaler for distribution with 0 mean and 1 std., normal distributed data
data_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

data_prep = data_pipeline.fit_transform(data_num)

X_train, X_test, y_train, y_test = train_test_split(data_prep, data_labels, test_size= 0.2, random_state=42)

# %% [markdown]
# Model Testing Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

#define model, 50 different trees
rnd_reg = RandomForestRegressor(n_estimators=50, n_jobs=-1)

#train model
rnd_reg.fit(X_train, y_train)

#prepare a data frame for the important features
importances = rnd_reg.feature_importances_
features = ['Matrizenradius [mm ]', 'Stempelkantenradius [mm]', 'Blechdicke [mm]',
            'Platinenabmessung [mm]', '1/4 Niederhalterkraft [N]', 'Ziehtiefe [mm]']

# Create a DataFrame to display feature importance, sorted descending
feat_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

#show important features
display(feat_df)

#make some predicitons on train and test dataset
y_train_pred = rnd_reg.predict(X_train)
y_test_pred = rnd_reg.predict(X_test)

#calculate R2 Score for train and test data
r2_train = r2_score(y_train,y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

#Compare R2 Score for the first 10 instances
vergleich_df = pd.DataFrame({
    'True value' : y_test[:10],
    'Prediction' : y_test_pred[:10].flatten(),
    'Difference' : y_test[:10] - y_test_pred[:10].flatten()
 })
#print the result
print(f'\nR² Train: {r2_train:.4f} | R² Test: {r2_test:.4f}')
display(vergleich_df.style.background_gradient(cmap='RdYlGn_r'))

## Uncertainty for RF --> commin soon
# Out:
#                      Feature  Importance
# 5             Ziehtiefe [mm]    0.664954
# 1   Stempelkantenradius [mm]    0.167218
# 3     Platinenabmessung [mm]    0.159644
# 4  1/4 Niederhalterkraft [N]    0.005159
# 0       Matrizenradius [mm ]    0.002107
# 2            Blechdicke [mm]    0.000916
# R² Train: 0.9998 | R² Test: 0.9990
# <style type="text/css">
# #T_45266_row0_col0, #T_45266_row0_col1, #T_45266_row9_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_45266_row0_col2 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_45266_row1_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_45266_row1_col1 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_45266_row1_col2, #T_45266_row4_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_45266_row2_col0 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_45266_row2_col1, #T_45266_row5_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_45266_row2_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_45266_row3_col0, #T_45266_row3_col1, #T_45266_row9_col1 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_45266_row3_col2 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_45266_row4_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_45266_row4_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_45266_row5_col0, #T_45266_row5_col1, #T_45266_row6_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_45266_row6_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_45266_row6_col1 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_45266_row7_col0 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_45266_row7_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_45266_row7_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_45266_row8_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_45266_row8_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_45266_row8_col2 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_45266_row9_col0 {
#   background-color: #82c966;
#   color: #000000;
# }
# </style>
# <table id="T_45266">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45266_level0_col0" class="col_heading level0 col0" >True value</th>
#       <th id="T_45266_level0_col1" class="col_heading level0 col1" >Prediction</th>
#       <th id="T_45266_level0_col2" class="col_heading level0 col2" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45266_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45266_row0_col0" class="data row0 col0" >6.590000</td>
#       <td id="T_45266_row0_col1" class="data row0 col1" >6.555180</td>
#       <td id="T_45266_row0_col2" class="data row0 col2" >0.034820</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45266_row1_col0" class="data row1 col0" >8.100000</td>
#       <td id="T_45266_row1_col1" class="data row1 col1" >8.085960</td>
#       <td id="T_45266_row1_col2" class="data row1 col2" >0.014040</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45266_row2_col0" class="data row2 col0" >9.231000</td>
#       <td id="T_45266_row2_col1" class="data row2 col1" >9.190260</td>
#       <td id="T_45266_row2_col2" class="data row2 col2" >0.040740</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45266_row3_col0" class="data row3 col0" >7.623000</td>
#       <td id="T_45266_row3_col1" class="data row3 col1" >7.586240</td>
#       <td id="T_45266_row3_col2" class="data row3 col2" >0.036760</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45266_row4_col0" class="data row4 col0" >9.253500</td>
#       <td id="T_45266_row4_col1" class="data row4 col1" >9.266690</td>
#       <td id="T_45266_row4_col2" class="data row4 col2" >-0.013190</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45266_row5_col0" class="data row5 col0" >10.484500</td>
#       <td id="T_45266_row5_col1" class="data row5 col1" >10.471270</td>
#       <td id="T_45266_row5_col2" class="data row5 col2" >0.013230</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45266_row6_col0" class="data row6 col0" >8.219000</td>
#       <td id="T_45266_row6_col1" class="data row6 col1" >8.176930</td>
#       <td id="T_45266_row6_col2" class="data row6 col2" >0.042070</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45266_row7_col0" class="data row7 col0" >6.679500</td>
#       <td id="T_45266_row7_col1" class="data row7 col1" >6.675930</td>
#       <td id="T_45266_row7_col2" class="data row7 col2" >0.003570</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45266_row8_col0" class="data row8 col0" >8.614500</td>
#       <td id="T_45266_row8_col1" class="data row8 col1" >8.583350</td>
#       <td id="T_45266_row8_col2" class="data row8 col2" >0.031150</td>
#     </tr>
#     <tr>
#       <th id="T_45266_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45266_row9_col0" class="data row9 col0" >7.534500</td>
#       <td id="T_45266_row9_col1" class="data row9 col1" >7.581110</td>
#       <td id="T_45266_row9_col2" class="data row9 col2" >-0.046610</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Quantil Regression Forest, build on original forest, approximation because only the mean of each choosen leaf is used, not the real distribution in leaf node --> skgarden funktioniert aber nicht

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import numpy as np

#define model, 50 different trees
rnd_reg = RandomForestRegressor(n_estimators=10, n_jobs=-1)

#train model
rnd_reg.fit(X_train, y_train)

#prepare a data frame for the important features
importances = rnd_reg.feature_importances_
features = ['Matrizenradius [mm ]', 'Stempelkantenradius [mm]', 'Blechdicke [mm]',
            'Platinenabmessung [mm]', '1/4 Niederhalterkraft [N]', 'Ziehtiefe [mm]']

# Create a DataFrame to display feature importance, sorted descending
feat_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

#show important features
display(feat_df)

#calculate the predictions for each tree on the training data for R² Score
predictions_train = np.array([tree.predict(X_train) for tree in rnd_reg.estimators_])
quantil_50_train = np.percentile(predictions_train, 50, axis = 0)

#calculate the predictions for each tree
predictions = np.array([tree.predict(X_test) for tree in rnd_reg.estimators_])

#get the quantils
quantil_2_5 = np.percentile(predictions, 2.5, axis = 0)
quantil_50 = np.percentile(predictions, 50, axis = 0)
quantil_97_5 = np.percentile(predictions, 97.5, axis = 0)

# Zeige das Ergebnis für das 50. Quantil (Median) an
print("Quantil 2.5 (Median) der Vorhersagen:\n", quantil_2_5)
print("Quantil 50 (Median) der Vorhersagen:\n", quantil_50)
print("Quantil 97.5 (Median) der Vorhersagen:\n", quantil_97_5)

r2_train = r2_score(y_train, quantil_50_train)
r2_test = r2_score(y_test,quantil_50)

#Compare R2 Score for the first 10 instances
vergleich_df = pd.DataFrame({
    'True value' : y_test[:10],
    'Prediction' : quantil_50[:10].flatten(),
    'Difference' : y_test[:10] - quantil_50[:10].flatten()
 })
#print the result
print(f'\nR² Train: {r2_train:.4f} | R² Test: {r2_test:.4f}')
display(vergleich_df.style.background_gradient(cmap='RdYlGn_r'))

# Check whether each true value lies within the 95% confidence interval
# If yes, the point will be green; if not, red
in_interval = (y_test >= quantil_2_5) & (y_test <= quantil_97_5)
colors = ['tab:green' if inside else 'tab:red' for inside in in_interval]

# Calculate coverage (percentage of true values within the CI)
coverage = np.mean(in_interval) * 100  # in percentage

# Print the coverage value
print(f"Coverage: {coverage:.2f}%")

# Plotting the prediction with uncertainty and true values
plt.figure(figsize=(12, 5))
x_axis = np.arange(len(X_test))

# Plot predicted mean
plt.plot(x_axis, quantil_50, label="Prediction (mean)", color='tab:blue')

# Shade the 95% confidence interval (±2 standard deviations)
plt.fill_between(x_axis, quantil_2_5, quantil_97_5,
                 alpha=0.4, color='tab:blue', label='95% Confidence Interval')

# Plot true target values as orange dots
plt.scatter(x_axis, y_test, label="True Values", c=colors, s=25, zorder=3)

# Add plot labels and formatting
plt.title("QRF Prediction on Testdata with Uncertainty")
plt.xlabel("Test Point Index")
plt.ylabel("x_Einzug [mm]")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#                      Feature  Importance
# 5             Ziehtiefe [mm]    0.661522
# 1   Stempelkantenradius [mm]    0.165866
# 3     Platinenabmessung [mm]    0.164480
# 4  1/4 Niederhalterkraft [N]    0.005101
# 0       Matrizenradius [mm ]    0.002172
# 2            Blechdicke [mm]    0.000859
# Quantil 2.5 (Median) der Vorhersagen:
#  [ 6.5047375  8.052      9.1385625  7.568575   9.2095    10.317
#   8.1462     6.5885     8.5455     7.482      9.8395     6.9304
#   7.9288625  7.1605     6.3213875  8.5323125  8.1033625  6.9605
#   9.8395     8.0855     7.589      7.9515     9.752025   6.852
#   7.55       7.0481     9.2865     7.4357     6.352675   6.93105
#   8.661      8.3547     7.1585     9.8640625  6.3213875  6.103
#   7.3715     9.8755     8.6645     9.0635     8.641      7.3804
#   6.511      6.0685375  6.9655125  9.11725   10.299      7.02315
#   8.1286625  7.443      8.2095     7.678      6.0089     6.3285
#   9.077      9.6895     6.852      7.96365    9.0735     8.1023125
#   8.4325     6.852      9.897775   8.708      6.1260625  9.7625
#   7.590675   7.6515    10.5403875  9.2073375  9.332825   6.779325
#   6.5885     7.917      7.6515     6.9852375 10.317      6.9794625
#   6.569525   7.38795    9.0225     6.2055     9.0125     8.1624625
#   9.0895375  7.0468     6.7575     7.007      7.02345    7.974
#   7.1115     8.0829375  8.018      9.9745     6.0565     8.5455
#   7.9822125  9.173075   9.8712375  6.5885     9.17165    7.241
#   8.3646     8.6975     9.077      8.088      8.4915     9.102525
#   8.486      6.4314375  8.0115     7.4135     8.1624625  6.5680625
#   8.145      8.0645     8.5885     8.4915     9.2073375  9.293
#   8.691      9.6561625  9.0277875  7.003      7.916      8.996775
#   7.917      8.0655     8.4818625  7.867      8.2095     7.0045
#   8.007      7.0555     6.8981125  8.6975     7.433      6.846175
#   9.8095875  9.6106125  8.4824     9.815      6.959725   8.208
#   6.626      9.500125 ]
{
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_65ad5_row2_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_65ad5_row2_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_65ad5_row3_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_65ad5_row3_col1 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_65ad5_row3_col2 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_65ad5_row4_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_65ad5_row4_col1 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_65ad5_row4_col2, #T_65ad5_row5_col0, #T_65ad5_row5_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_65ad5_row6_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_65ad5_row6_col1 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_65ad5_row6_col2 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_65ad5_row7_col0 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_65ad5_row7_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_65ad5_row7_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_65ad5_row8_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_65ad5_row8_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_65ad5_row8_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_65ad5_row9_col0 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_65ad5_row9_col1 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_65ad5_row9_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_65ad5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65ad5_level0_col0" class="col_heading level0 col0" >True value</th>
#       <th id="T_65ad5_level0_col1" class="col_heading level0 col1" >Prediction</th>
#       <th id="T_65ad5_level0_col2" class="col_heading level0 col2" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65ad5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65ad5_row0_col0" class="data row0 col0" >6.590000</td>
#       <td id="T_65ad5_row0_col1" class="data row0 col1" >6.557000</td>
#       <td id="T_65ad5_row0_col2" class="data row0 col2" >0.033000</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_65ad5_row1_col0" class="data row1 col0" >8.100000</td>
#       <td id="T_65ad5_row1_col1" class="data row1 col1" >8.090500</td>
#       <td id="T_65ad5_row1_col2" class="data row1 col2" >0.009500</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_65ad5_row2_col0" class="data row2 col0" >9.231000</td>
#       <td id="T_65ad5_row2_col1" class="data row2 col1" >9.196000</td>
#       <td id="T_65ad5_row2_col2" class="data row2 col2" >0.035000</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_65ad5_row3_col0" class="data row3 col0" >7.623000</td>
#       <td id="T_65ad5_row3_col1" class="data row3 col1" >7.589500</td>
#       <td id="T_65ad5_row3_col2" class="data row3 col2" >0.033500</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_65ad5_row4_col0" class="data row4 col0" >9.253500</td>
#       <td id="T_65ad5_row4_col1" class="data row4 col1" >9.209500</td>
#       <td id="T_65ad5_row4_col2" class="data row4 col2" >0.044000</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_65ad5_row5_col0" class="data row5 col0" >10.484500</td>
#       <td id="T_65ad5_row5_col1" class="data row5 col1" >10.571500</td>
#       <td id="T_65ad5_row5_col2" class="data row5 col2" >-0.087000</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_65ad5_row6_col0" class="data row6 col0" >8.219000</td>
#       <td id="T_65ad5_row6_col1" class="data row6 col1" >8.189000</td>
#       <td id="T_65ad5_row6_col2" class="data row6 col2" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_65ad5_row7_col0" class="data row7 col0" >6.679500</td>
#       <td id="T_65ad5_row7_col1" class="data row7 col1" >6.696500</td>
#       <td id="T_65ad5_row7_col2" class="data row7 col2" >-0.017000</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_65ad5_row8_col0" class="data row8 col0" >8.614500</td>
#       <td id="T_65ad5_row8_col1" class="data row8 col1" >8.582000</td>
#       <td id="T_65ad5_row8_col2" class="data row8 col2" >0.032500</td>
#     </tr>
#     <tr>
#       <th id="T_65ad5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_65ad5_row9_col0" class="data row9 col0" >7.534500</td>
#       <td id="T_65ad5_row9_col1" class="data row9 col1" >7.602500</td>
#       <td id="T_65ad5_row9_col2" class="data row9 col2" >-0.068000</td>
#     </tr>
#   </tbody>
# </table>
# Coverage: 69.86%
